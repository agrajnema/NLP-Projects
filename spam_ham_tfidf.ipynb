# %% [markdown]
# ##### Spam Ham project using Bag of Words (BOW)
#
# Steps:
# 1) Import dataset
# 2) Preprocess dataset - convert to lowercase, remove special characters using regex, lemmatize/stem
# 3) Test-Train split (do this before converting words to vectors so that there is no leakage of data between train and test)
# 4) Convert words to vectors using TF-IDF
# 5) Train using ML algorithm like Naive Bayes
# 6) Predict and check accuracy

# %%
import pandas as pd

# %%
# Load the dataset
messages = pd.read_csv('./dataset/SMSSpamCollection.csv', sep='\t', names=['label', 'message'])

# %%
messages.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
import nltk

# %%
import re
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
lemmatizer = WordNetLemmatizer()

# %%
# Preprocess the data

corpus = []

for i in range(0,len(messages)):
    words = messages['message'][i].lower() #change all words to lowercase
    words = re.sub('^a-z',' ', words) # remove special characters
    words = words.split()
    words = [lemmatizer.lemmatize(word) for word in words if word not in set(stopwords.words('english'))]
    words = ' '.join(words)
    corpus.append(words)

corpus
# Out:
# ['go jurong point, crazy.. available bugis n great world la e buffet... cine got amore wat...',
#  'ok lar... joking wif u oni...',
#  "free entry 2 wkly comp win fa cup final tkts 21st may 2005. text fa 87121 receive entry question(std txt rate)t&c's apply 08452810075over18's",
#  'u dun say early hor... u c already say...',
#  'nah think go usf, life around though',
#  "freemsg hey darling 3 week's word back! i'd like fun still? tb ok! xxx std chgs send, £1.50 rcv",
#  'even brother like speak me. treat like aid patent.',
#  "per request 'melle melle (oru minnaminunginte nurungu vettam)' set callertune callers. press *9 copy friend callertune",
#  'winner!! valued network customer selected receivea £900 prize reward! claim call 09061701461. claim code kl341. valid 12 hour only.',
#  'mobile 11 month more? u r entitled update latest colour mobile camera free! call mobile update co free 08002986030',
#  "i'm gonna home soon want talk stuff anymore tonight, k? i've cried enough today.",
#  'six chance win cash! 100 20,000 pound txt> csh11 send 87575. cost 150p/day, 6days, 16+ tsandcs apply reply hl 4 info',
#  'urgent! 1 week free membership £100,000 prize jackpot! txt word: claim no: 81010 t&c www.dbuk.net lccltd pobox 4403ldnw1a7rw18',
#  "i've searching right word thank breather. promise wont take help granted fulfil promise. wonderful blessing times.",
#  'date sunday will!!',
#  'xxxmobilemovieclub: use credit, click wap link next txt message click here>> http://wap. xxxmobilemovieclub.com?n=qjkgighjjgcbl',
#  "oh k...i'm watching here:)",
#  'eh u remember 2 spell name... yes did. v naughty make v wet.',
#  'fine that\x92s way u feel. that\x92s way gota b',
#  'england v macedonia - dont miss goals/team news. txt ur national team 87077 eg england 87077 try:wales, scotland 4txt/ú1.20 poboxox36504w45wq 16+',
#  'seriously spell name?',
#  'i‘m going try 2 month ha ha joking',
#  'ü pay first lar... da stock comin...',
#  'aft finish lunch go str lor. ard 3 smth lor. u finish ur lunch already?',
#  'ffffffffff. alright way meet sooner?',
#  "forced eat slice. i'm really hungry tho. sucks. mark getting worried. know i'm sick turn pizza. lol",
#  'lol always convincing.',
#  "catch bus ? frying egg ? make tea? eating mom's left dinner ? feel love ?",
#  "i'm back &amp; we're packing car now, i'll let know there's room",
#  'ahhh. work. vaguely remember that! feel like? lol',
#  "wait that's still clear, sure sarcastic that's x want live u",
#  'yeah got 2 v apologetic. n fallen actin like spoilt child got caught that. till 2! go there! badly cheers. you?',
#  'k tell anything you.',
#  'fear fainting housework did? quick cuppa',
#  'thanks subscription ringtone uk mobile charged £5/month please confirm replying yes no. reply charged',
#  'yup... ok go home look timing msg ü again... xuhui going learn 2nd may lesson 8am',
#  "oops, i'll let know roommate's done",
#  'see letter b car',
#  'anything lor... u decide...',
#  "hello! how's saturday go? texting see decided anything tomo. i'm trying invite anything!",
#  'pls go ahead watts. wanted sure. great weekend. abiola',
#  'forget tell ? want , need you, crave ... ... love sweet arabian steed ... mmmmmm ... yummy',
#  '07732584351 - rodger burn - msg = tried call reply sm free nokia mobile + free camcorder. please call 08000930705 delivery tomorrow',
#  'seeing?',
#  'great! hope like man well endowed. &lt;#&gt; inches...',
#  'calls..messages..missed call',
#  'get hep b immunisation nigeria.',
#  'fair enough, anything going on?',
#  "yeah hopefully, tyler can't could maybe ask around bit",
#  "u know stubborn am. even want go hospital. kept telling mark i'm weak sucker. hospital weak suckers.",
#  'thinked me. first time saw class.',
#  'gram usually run like &lt;#&gt; , half eighth smarter though get almost whole second gram &lt;#&gt;',
#  "k fyi x ride early tomorrow morning he's crashing place tonight",
#  'wow. never realized embarassed accomodations. thought liked it, since best could always seemed happy "the cave". i\'m sorry give. i\'m sorry offered. i\'m sorry room embarassing.',
#  'sms. ac sptv: new jersey devil detroit red wing play ice hockey. correct incorrect? end? reply end sptv',
#  'know mallika sherawat yesterday? find @ &lt;url&gt;',
#  'congrats! 1 year special cinema pas 2 yours. call 09061209465 now! c suprman v, matrix3, starwars3, etc 4 free! bx420-ip4-5we. 150pm. dont miss out!',
#  "sorry, i'll call later meeting.",
#  'tell reached',
#  'yes..gauti sehwag odi series.',
#  "gonna pick $1 burger way home. can't even move. pain killing me.",
#  'ha ha ha good joke. girl situation seekers.',
#  'part checking iq',
#  'sorry roommate took forever, ok come now?',
#  'ok lar double check wif da hair dresser already said wun cut v short. said cut look nice.',
#  'valued customer, pleased advise following recent review mob no. awarded £1500 bonus prize, call 09066364589',
#  'today "song dedicated day.." song u dedicate me? send ur valuable frnds first rply me...',
#  'urgent ur awarded complimentary trip eurodisinc trav, aco&entry41 £1000. claim txt dis 87121 18+6*£1.50(morefrmmob. shracomorsglsuplt)10, ls1 3aj',
#  'hear new "divorce barbie"? come ken\'s stuff!',
#  'plane give month end.',
#  'wah lucky man... save money... hee...',
#  'finished class you.',
#  'hi babe im home wanna something? xx',
#  'k..k:)where you?how performed?',
#  'u call now...',
#  'waiting machan. call free.',
#  'thats cool. gentleman treat dignity respect.',
#  'like people much:) shy pa.',
#  'operate &lt;#&gt;',
#  "here. still looking job. much ta's earn there.",
#  "sorry, i'll call later",
#  'k. call ah?',
#  'ok way home hi hi',
#  'place man',
#  'yup next stop.',
#  'call later, network. urgnt, sm me.',
#  "real u getting yo? need 2 ticket one jacket i'm done. already used multis.",
#  "yes started send request make pain came back i'm back bed. double coin factory too. gotta cash nitros.",
#  "i'm really still tonight babe",
#  'ela kano.,il download, come wen ur free..',
#  'yeah do! don‘t stand close tho- you‘ll catch something!',
#  'sorry pain. ok meet another night? spent late afternoon casualty mean done stuff42moro includes time sheet that. sorry.',
#  'smile pleasure smile pain smile trouble pours like rain smile sum1 hurt u smile becoz someone still love see u smiling!!',
#  'please call customer service representative 0800 169 6031 10am-9pm guaranteed £1000 cash £5000 prize!',
#  'havent planning buy later. check already lido got 530 show e afternoon. u finish work already?',
#  'free ringtone waiting collected. simply text password "mix" 85069 verify. get usher britney. fml, po box 5249, mk17 92h. 450ppw 16',
#  'watching telugu movie..wat abt u?',
#  'see. finish load loan pay',
#  'hi. wk ok - hols now! yes bit run. forgot hairdresser appointment four need get home n shower beforehand. cause prob u?"',
#  'see cup coffee animation',
#  'please text anymore. nothing else say.',
#  'okay name ur price long legal! wen pick up? u ave x am xx',
#  "i'm still looking car buy. gone 4the driving test yet.",
#  "per request 'melle melle (oru minnaminunginte nurungu vettam)' set callertune callers. press *9 copy friend callertune",
#  'wow. right! mean that. guess gave boston men changed search location nyc, something changed. cuz signin page still say boston.',
#  'umma life vava umma love lot dear',
#  'thanks lot wish birthday. thanks making birthday truly memorable.',
#  "aight, i'll hit get cash",
#  'would ip address test considering computer minecraft server',
#  'know! grumpy old people. mom like better lying. always one play jokes...',
#  "dont worry. guess he's busy.",
#  'plural noun research?',
#  'going dinner.msg after.',
#  "i'm ok wif co like 2 try new things. scared u dun like mah. co u said loud.",
#  'gent! trying contact you. last weekend draw show £1000 prize guaranteed. call 09064012160. claim code k52. valid 12hrs only. 150ppm',
#  "wa, ur openin sentence formal... anyway, i'm fine too, juz tt i'm eatin much n puttin weight...haha... anythin special happened?",
#  "entered cabin pa said, '' happy b'day bos !!''. felt special. askd 4 lunch. lunch invited apartment. went there.",
#  'winner u specially selected 2 receive £1000 4* holiday (flights inc) speak live operator 2 claim 0871277810910p/min (18+)',
#  'goodo! yes must speak friday - egg-potato ratio tortilla needed!',
#  "hmm...my uncle informed he's paying school directly. pls buy food.",
#  'private! 2004 account statement 07742676969 show 786 unredeemed bonus points. claim call 08719180248 identifier code: 45239 expires',
#  'urgent! mobile no. awarded £2000 bonus caller prize 5/9/03 final try contact u! call landline 09064019788 box42wr29c, 150ppm',
#  'new address -apples&pairs&all malarky',
#  'today voda number ending 7548 selected receive $350 award. match please call 08712300220 quoting claim code 4041 standard rate app',
#  'going sao mu today. done 12',
#  "ü predict wat time ü'll finish buying?",
#  'good stuff, do.',
#  'know,yetunde sent money yet. sent text bother sending. over, dont involve anything. imposed anything first place that, apologise.',
#  'room.',
#  'hey girl. r u? hope u r well del r bak! long time c! give call sum time lucyxx',
#  'k..k:)how much cost?',
#  "i'm home.",
#  'dear, call tmorrow.pls accomodate.',
#  'first answer question.',
#  'sunshine quiz wkly q! win top sony dvd player u know country algarve in? txt ansr 82277. £1.50 sp:tyrone',
#  "want 2 get laid tonight? want real dogging location sent direct 2 ur mob? join uk's largest dogging network bt txting gravel 69888! nt. ec2a. 31p.msg@150p",
#  'haf msn. yijue@hotmail.com',
#  'there. call meet',
#  'no. check room befor activity',
#  'rcv msg chat svc. free hardcore service text go to: 69988 u get nothing u must age verify yr network & try',
#  'got c... lazy type... forgot ü lect... saw pouch like v nice...',
#  'k, text way',
#  'sir, waiting mail.',
#  'swt thought: "nver get tired little thing 4 lovable persons.." coz..somtimes little thing occupy biggest part hearts.. gud ni8',
#  'know are. pls open back?',
#  'yes see ya dot',
#  'whats staff name taking class us?',
#  "freemsg replied text? i'm randy, sexy, female live local. luv hear u. netcollex ltd 08700621170150p per msg reply stop end",
#  'ummma.will call check in.our life begin qatar pls pray hard.',
#  'k..i deleted contact why?',
#  'sindu got job birla soft ..',
#  "wine flowing i'm nevering..",
#  'yup thk cine better co need 2 go 2 plaza mah.',
#  'ok... ur typical reply...',
#  "per request 'melle melle (oru minnaminunginte nurungu vettam)' set callertune callers. press *9 copy friend callertune",
#  'everywhere dirt, floor, windows, even shirt. sometimes open mouth, come flowing out. dream world without you, half chore too. time joy me, lot tv show i.ll see. guess like thing must exist, like rain, hail mist, time done, become one.',
#  'aaooooright work?',
#  "i'm leaving house now...",
#  'hello, love. doing? get interview today? happy? good boy? think me?are missing ?',
#  'customer service annoncement. new year delivery waiting you. please call 07046744435 arrange delivery',
#  'winner u specially selected 2 receive £1000 cash 4* holiday (flights inc) speak live operator 2 claim 0871277810810',
#  "keep safe need miss already envy everyone see's real life",
#  'new car house parents.:)i new job hand:)',
#  "i'm love you. i'm excited day spend you. make happy.",
#  '-pls stop bootydelious (32/f) inviting friend. reply yes-434 no-434 see her: www.sms.ac/u/bootydelious stop? send stop frnd 62468',
#  'bangbabes ur order way. u receive service msg 2 download ur content. u not, goto wap. bangb. tv ur mobile internet/service menu',
#  'place ur point e culture module already.',
#  'urgent! trying contact you. last weekend draw show £900 prize guaranteed. call 09061701939. claim code s89. valid 12hrs',
#  "hi frnd, best way avoid missunderstding wit beloved one's?",
#  'great escape. fancy bridge need lager. see tomo',
#  'yes :)it completely form:)clark also utter waste.',
#  'sir, need axis bank account bank address.',
#  'hmmm.. thk sure got time hop ard... ya, go 4 free abt... muz call u discus liao...',
#  'time coming later?',
#  'bloody hell, cant believe forgot surname mr . ill give u clue, spanish begin m...',
#  "well, i'm gonna finish bath now. good...fine night.",
#  'let know got money carlos make call',
#  'u still going mall?',
#  'turn friend staying whole show back til ~ &lt;#&gt; , feel free go ahead smoke $ &lt;#&gt; worth',
#  'text her. doesnt reply let know log',
#  "hi! spoke maneesha v. we'd like know satisfied experience. reply toll free yes no.",
#  'lifted hope offer money. need. especially end month approach hurt studying. anyways gr8 weekend',
#  'lol no. u trust me.',
#  'ok. gentleman treat dignity respect.',
#  'will, guy close?',
#  'going nothing great.bye',
#  "hello handsome ! finding job ? lazy ? working towards getting back net mummy ? where's boytoy ? miss ?",
#  'haha awesome, minute',
#  'please call customer service representative freephone 0808 145 4742 9am-11pm guaranteed £1000 cash £5000 prize!',
#  'got xmas radio times. get',
#  'jus reached home. go bathe first. si using net tell u finish k...',
#  'unique enough? find 30th august. www.areyouunique.co.uk',
#  "i'm sorry. i've joined league people dont keep touch. mean great deal me. friend time even great personal cost. great week.|",
#  'hi :)finally completed course:)',
#  'stop itself. however suggest stay someone able give or every stool.',
#  'doing? hope settled new school year. wishin gr8 day',
#  'gud mrng dear hav nice day',
#  'u got person story',
#  'hamster dead? hey tmr meet 1pm orchard mrt?',
#  'hi kate evening? hope see tomorrow bit bloody babyjontet! txt back u can. :) xxx',
#  'found it, enc &lt;#&gt; , at?',
#  'sent &lt;#&gt; buck',
#  'hello darlin ive finished college txt u finish u love kate xxx',
#  'account refilled successfully inr &lt;decimal&gt; . keralacircle prepaid account balance r &lt;decimal&gt; . transaction id kr &lt;#&gt; .',
#  'goodmorning sleeping ga.',
#  'u call alter 11 ok.',
#  'ü say like dat dun buy ericsson oso cannot oredi lar...',
#  "entered cabin pa said, '' happy b'day bos !!''. felt special. askd 4 lunch. lunch invited apartment. went there.",
#  'aight yo, dat straight dogg',
#  'please give u connection today &lt;decimal&gt; refund bill',
#  ':) shoot big load get ready!',
#  "what's bruv, hope great break. rewarding semester.",
#  'home always chat',
#  'k:)k:)good:)study well.',
#  'yup... ü noe leh...',
#  'sound great! home now?',
#  'finally match heading towards draw prediction.',
#  'tired. slept well past nights.',
#  'easy ah?sen got selected mean good..',
#  'take exam march 3',
#  "yeah should. think use gt atm register. sure there's anyway help let know. sure ready.",
#  'ok prob. take ur time.',
#  'o called ubandu run without installing hard disk...you use o copy important file system give repair shop..',
#  "sorry, i'll call later",
#  'u say leh... course nothing happen lar. say v romantic jus bit lor. thk e nite scenery nice leh.',
#  '500 new mobile 2004, must go! txt: nokia no: 89545 & collect today!from £1 www.4-tc.biz 2optout 087187262701.50gbp/mtmsg18',
#  'would really appreciate call me. need someone talk to.',
#  'u meet ur dream partner soon? ur career 2 flyng start? 2 find free, txt horo followed ur star sign, e. g. horo aries',
#  'hey company elama po mudyadhu.',
#  'life strict teacher... bcoz teacher teach lesson &amp; conduct exam, life first conduct exam &amp; teach lessons. happy morning. . .',
#  'dear good morning',
#  'get gandhipuram walk cross cut road. right side &lt;#&gt; street road turn first right.',
#  'dear going rubber place',
#  "sorry battery died, yeah i'm",
#  'yes:)here tv always available work place..',
#  'text & meet someone sexy today. u find date even flirt u. join 4 10p. reply name & age eg sam 25. 18 -msg recd@thirtyeight penny',
#  'printed oh. &lt;#&gt; come upstairs',
#  'ill little closer like bus stop street',
#  'you?when wil reach here?',
#  "new theory: argument win situation, loses person. dont argue ur friend just.. . . . kick &amp; say, i'm always correct.!",
#  'u 447801259231 secret admirer looking 2 make contact u-find r*reveal think ur special-call 09058094597',
#  'tomarrow final hearing laptop case cant.',
#  'pleassssssseeeeee tel v avent done sportsx',
#  'okay. no, shining on. meant signing, sound better.',
#  "although told u dat i'm baig face watch really like e watch u gave co fr u. thanx 4 everything dat u've done today, i'm touched...",
#  'u remember old commercial?',
#  'late. said website. dont slipper',
#  'asked call ok',
#  'kallis wont bat 2nd innings.',
#  'didnt work oh. ok goodnight then. i.ll fix ready time wake up. dearly missed good night sleep.',
#  'congratulation ur awarded 500 cd voucher 125gift guaranteed & free entry 2 100 wkly draw txt music 87066 tncs www.ldew.com1win150ppmx3age16',
#  'ranjith cal drpd deeraj deepak 5min hold',
#  'wen ur lovable bcums angry wid u, dnt take seriously.. coz angry childish n true way showing deep affection, care n luv!.. kettoda manda... nice day da.',
#  'doing?how you?',
#  'ups 3days also, shipping company take 2wks. way usps take week get lag may bribe nipost get stuff.',
#  "i'm back, lemme know ready",
#  "necessarily expect done get back though i'm headin",
#  'mmm yummy babe ... nice jolt suzy',
#  'lover ? need ...',
#  'tried contact reply offer video handset? 750 anytime network mins? unlimited text? camcorder? reply call 08000930705',
#  'i‘m parked next mini!!!! coming today think?',
#  'yup',
#  "anyway i'm going shopping now. co si done yet. dun disturb u liao.",
#  'no. luton 0125698789 ring ur around! h*',
#  'hey really horny want chat see naked text hot 69698 text charged 150pm unsubscribe text stop 69698',
#  'dint come us.',
#  'same. wana plan trip sometme',
#  'sure yet, still trying get hold',
#  'ur ringtone service changed! 25 free credits! go club4mobiles.com choose content now! stop? txt club stop 87070. 150p/wk club4 po box1146 mk45 2wt',
#  'evo. download flash. jealous?',
#  'ringtone club: get uk single chart mobile week choose top quality ringtone! message free charge.',
#  "come mu, we're sorting narcotic situation",
#  'night ended another day, morning come special way. may smile like sunny ray leaf worry blue blue bay.',
#  'hmv bonus special 500 pound genuine hmv voucher won. answer 4 easy questions. play now! send hmv 86688 info:www.100percent-real.com',
#  'usf guess, might well take 1 car',
#  'objection. bf coming.',
#  'thanx...',
#  'tell rob mack gf theater',
#  "awesome, i'll see bit",
#  'sent it. type food like?',
#  'done? handed in? celebration full swing yet?',
#  'got called tool?',
#  'wen u miss someone, person definitely special u..... person special, miss them, keep-in-touch gdeve..',
#  'ok. asked money far',
#  'okie...',
#  "yeah think usual guy's still passed last night, get ahold anybody let know i'll throw",
#  'k, might come tonight class let early',
#  'ok..',
#  'hi baby im cruisin girl friend r u 2? give call hour home thats alright fone fone love jenny xxx',
#  'life mean lot me, love life, love people life, world call friends, call world:-).. ge:-)..',
#  'dear,shall mail tonite.busy street,shall update tonite.things looking ok.varunnathu edukkukayee raksha ollu.but good one real sense.',
#  'hey told name gautham ah?',
#  'haf u found him? feel stupid da v cam working.',
#  'oops. 4 got bit.',
#  'much buzy',
#  'accidentally deleted message. resend please.',
#  "t-mobile customer may claim free camera phone upgrade & pay & go sim card loyalty. call 0845 021 3680.offer end 28thfeb.t&c's apply",
#  'unless situation go gurl would appropriate',
#  'hurt me... tease me... make cry... end life die plz keep one rose grave say stupid miss u.. nice day bslvyl',
#  'cant pick phone right now. pls send message',
#  "need coffee run tomo?can't believe time week already",
#  'awesome, remember last time got somebody high first time diesel :v',
#  'shit really shocking scary, cant imagine second. def night out. u think somewhere could crash night, save taxi?',
#  'oh way food fridge! want go meal tonight?',
#  'womdarfull actor',
#  'sms. ac blind date 4u!: rodds1 21/m aberdeen, united kingdom. check http://img. sms. ac/w/icmb3cktz8r7!-4 blind date send hide',
#  'yup... remb... think book...',
#  'jos ask u wana meet up?',
#  'lol yes. friendship hanging thread cause u buy stuff.',
#  'themob> check newest selection content, games, tones, gossip, babe sport, keep mobile fit funky text wap 82468',
#  'garage keys? bookshelf',
#  'today accept day..u accept as? brother sister lover dear1 best1 clos1 lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd rply mean enemy',
#  'think ur smart ? win £200 week weekly quiz, text play 85222 now!t&cs winnersclub po box 84, m26 3uz. 16+. gbp1.50/week',
#  "say he'll give call friend's got money he's definitely buying end week",
#  'hi way u 2day, normal way&this real me. ur unique&i hope know u 4 rest mylife. hope u find wot lost.',
#  'made day. great day too.',
#  'k.k:)advance happy pongal.',
#  'hmmm... guess go 4 kb n power yoga... haha, dunno tahan power yoga anot... thk got lo oso, forgot liao...',
#  "really dude, friend i'm afraid :(",
#  'december only! mobile 11mths+? entitled update latest colour camera mobile free! call mobile update co free 08002986906',
#  'coffee cake, guess...',
#  'merry christmas babe, love ya *kisses*',
#  'hey... dont go watch x men lunch... haha',
#  'cud u tell ppl im gona b bit l8 co 2 bus hav gon past co full & im still waitin 4 1. pete x',
#  "would great. we'll guild. could meet bristol road somewhere - get touch weekend. plan take flight! good week",
#  'problem. doing?',
#  'calls..messages..missed call',
#  'hi da:)how today class?',
#  "i'd say that's good sign but, well, know track record reading woman",
#  'cool, text parked',
#  "i'm reading text sent you. meant joke. read light",
#  'k.k:)apo k.good movie.',
#  'maybe could get book tomo return immediately ..? something.',
#  'call germany 1 penny per minute! call fixed line via access number 0844 861 85 85. prepayment. direct access!',
#  "chance might evaporated soon violated privacy stealing phone number employer's paperwork. cool all. please contact report supervisor.",
#  'valentine day special! win £1000 quiz take partner trip lifetime! send go 83600 now. 150p/msg rcvd. custcare:08718720201.',
#  'ta-daaaaa! home babe, still ?',
#  'cool. come havent wined dined before?',
#  'sleeping..and surfing',
#  "sorry, i'll call later",
#  'u calling right? call hand phone...',
#  "ok that's great thanx lot.",
#  'take post come then! must 1000 text now! happy reading. one wiv hello caroline end favourite. bless',
#  'u hiding stranger?',
#  'interested like that.',
#  'sister cleared two round birla soft yesterday.',
#  'gudnite....tc...practice going',
#  'dis yijue. jus saw ur mail. case huiming havent sent u num. dis num.',
#  'one small prestige problem now.',
#  'fancy shag? do.interested? sextextuk.com txt xxuk suzy 69876. txts cost 1.50 per msg. tncs website. x',
#  'checking you. really miss seeing jeremiah. great month',
#  "nah can't help there, i've never iphone",
#  "car hour half i'm going apeshit",
#  "today sorry day.! ever angry you, ever misbehaved hurt you? plz plz slap urself bcoz, ur fault, i'm basically good",
#  'yo guy ever figure much need alcohol? jay trying figure much safely spend weed',
#  '&lt;#&gt; ish minute 5 minute ago. wtf.',
#  'thank calling.forgot say happy onam sirji.i fine remembered met insurance person.meet qatar insha allah.rakhesh, ex tata aig joined tissco,tayseer.',
#  'congratulation ur awarded 500 cd voucher 125gift guaranteed & free entry 2 100 wkly draw txt music 87066 tncs www.ldew.com1win150ppmx3age16',
#  'ur cash-balance currently 500 pound - maximize ur cash-in send cash 86688 150p/msg. cc: 08708800282 hg/suite342/2lands row/w1j6hl',
#  "i'm actor. work, work evening sleep late. since i'm unemployed moment, always sleep late. unemployed, every day saturday.",
#  'hello! got here, st andrews-boy long way! cold. keep posted',
#  'ha ha cool cool chikku chikku:-):-db-)',
#  'oh ok prob..',
#  "check audrey's status right",
#  'busy here. trying finish new year. looking forward finally meeting you...',
#  'good afternoon sunshine! dawn day ? refreshed happy alive? breathe air smile ? think you, love ... always',
#  'well know z take care me. worries.',
#  'update_now - xmas offer! latest motorola, sonyericsson & nokia & free bluetooth! double min & 1000 txt orange. call mobileupd8 08000839402 call2optout/f4q=',
#  'discount code rp176781. stop message reply stop. www.regalportfolio.co.uk. customer service 08717205546',
#  'wat uniform? get?',
#  'cool, text ready',
#  'hello boytoy ... geeee miss already woke up. wish bed me, cuddling me. love ...',
#  'spoil bed well :)',
#  "i'm going bath msg next &lt;#&gt; min..",
#  'cant keep talking people sure pay agree price. pls tell want really buy much willing pay',
#  'thanks ringtone order, reference t91. charged gbp 4 per week. unsubscribe anytime calling customer service 09057039994',
#  'say happen',
#  "could seen me..i did't recognise face.:)",
#  "well there's lot thing happening lindsay new year *sighs* bar ptbo blue heron something going",
#  'keep payasam rinu brings',
#  'taught ranjith sir called me. sm like that. becaus he verifying project. prabu told today pa dont mistake me..',
#  "guess that's worried. must know there's way body repair itself. i'm quite sure worry. we'll take slow. first tests, guide ovulation relax. nothing said reason worry i.ll keep followin up.",
#  'yeah sure, give couple minute track wallet',
#  'hey leave it. big deal:-) take care.',
#  'hey late ah... meet 945+',
#  'double min txts 4 6months free bluetooth orange. available sony, nokia motorola phones. call mobileupd8 08000839402 call2optout/n9dx',
#  'took mr owl 3 lick',
#  'customer place call you.',
#  'mm time dont like fun',
#  '4mths half price orange line rental & latest camera phone 4 free. phone 11mths ? call mobilesdirect free 08000938767 update now! or2stoptxt',
#  'yup lunch buffet now.. u eat already?',
#  'huh late... fr dinner?',
#  'hey sat going intro pilate only? kickboxing too?',
#  'morning ok.',
#  'yes think so. office lap room think thats last days. didnt shut',
#  'pick bout 7.30ish? time going?',
#  'performance award calculated every two month.not current one month period..',
#  'actually sleeping still might u call back. text gr8. rock sis. send u text wen wake.',
#  "always putting business there. put picture as facebook. one open people i've ever met. would think picture room would hurt you, make feel violated.",
#  'good evening sir, al salam wahleykkum.sharing happy news.by grace god, got offer tayseer,tissco joined.hope fine.inshah allah,meet sometime.rakhesh,visitor india.',
#  'hmmm...k...but want change field quickly da:-)i wanna get system administrator network administrator..',
#  'free ringtone text first 87131 poly text get 87131 true tone! help? 0845 2814032 16 1st free, tone 3x£150pw e£nd txt stop',
#  'dear chechi. talk',
#  'hair cream shipped.',
#  "none that's happening til get though",
#  'yep, great loxahatchee xmas tree burning &lt;#&gt; start hour',
#  'haha get used driving usf man, know lot stoner',
#  "well slightly disastrous class pm fav darlings! hope day ok. coffee wld good can't stay late tomorrow. time + place always?",
#  'hello! good week? fancy drink something later?',
#  'headin towards busetop',
#  'message:some text missing* sender:name missing* *number missing *sent:date missing *missing u lot thats everything missing sent via fullonsms.com',
#  'come room point iron plan weekend',
#  'co want thing',
#  "okies... i'll go yan jiu too... skip ard oso, go cine den go mrt one, blah blah blah...",
#  'bring home wendy =d',
#  '100 dating service cal;l 09064012103 box334sk38ch',
#  'whatsup there. dont u want sleep',
#  'alright new goal',
#  'free entry £250 weekly competition text word win 80086 now. 18 t&c www.txttowin.co.uk',
#  "alright, i'll head minutes, text meet",
#  'send logo 2 ur lover - 2 name joined heart. txt love name1 name2 mobno eg love adam eve 07123456789 87077 yahoo! pobox36504w45wq txtno 4 ad 150p',
#  "yes:)from last week i'm taking live call.",
#  'someone contacted dating service entered phone fancy you! find call landline 09111032124 . pobox12n146tf150p',
#  'siva hostel aha:-.',
#  'urgent! mobile number awarded £2000 prize guaranteed. call 09058094455 land line. claim 3030. valid 12hrs',
#  'send ur friend receive something ur voice..... speaking expression? 1.childish 2.naughty 3.sentiment 4.rowdy 5.ful attitude 6.romantic 7.shy 8.attractive 9.funny &lt;#&gt; .irritating &lt;#&gt; .lovable. reply me..',
#  "ok. she'll ok. guess",
#  'aathi..where dear..',
#  'pain urination thing else?',
#  '7 esplanade.. ü mind giving lift co got car today..',
#  'wnt buy bmw car urgently..its vry urgent.but hv shortage &lt;#&gt; lacs.there source arng dis amt. &lt;#&gt; lacs..thats prob',
#  'home watching tv lor.',
#  'usually take fifteen fucking minute respond yes question',
#  'congrats! nokia 3650 video camera phone call 09066382422 call cost 150ppm ave call 3mins vary mobile 16+ close 300603 post bcm4284 ldn wc1n3xx',
#  'booked ticket pongal?',
#  "available now? i'm like right around hillsborough &amp; &lt;#&gt; th",
#  'message sent askin &lt;#&gt; dollars. shoul pay &lt;#&gt; &lt;#&gt; ?',
#  "ask g iouri, i've told story like ten time already",
#  'long applebees fucking take',
#  'hi hope u get txt~journey hasnt gd,now 50 min late think.',
#  'to. like love arrange.',
#  'yes..he really great..bhaji told kallis best cricketer sachin world:).very tough get out.',
#  'supposed wake &gt;:(',
#  'oic... saw tot din c me... found group liao...',
#  "sorry, i'll call later",
#  'hey hey werethe monkeespeople say monkeyaround! howdy gorgeous, howu doin? foundurself jobyet sausage?love jen xxx',
#  "sorry, battery died, come i'm getting gram now, where's place?",
#  'well done, blimey, exercise, yeah, kinda remember wot is, hmm.',
#  'wont get concentration dear know mind everything :-)',
#  'lol ... made plan new years?',
#  '10 min later k...',
#  'hank lotsly!',
#  'thanks hope good day today',
#  'k:)k:)what detail want transfer?acc enough?',
#  'ok tell stay out. yeah tough optimistic thing improve month.',
#  "loan purpose £500 - £75,000. homeowner + tenant welcome. previously refused? still help. call free 0800 1956669 text back 'help'",
#  'si si. think ill go make oreo truffles.',
#  'look amy ure beautiful, intelligent woman like u lot. know u don\x92t like like don\x92t worry.',
#  "hope that's result consistently intelligent kind. start asking practicum link keep ear open best. ttyl",
#  '1.20 call cost. guess isnt bad. miss ya, need ya, want ya, love ya',
#  'going thru different feeling.wavering decision coping individual.time heal everything believe.',
#  'u go? phone gonna die stay',
#  'great. never better. day give even reason thank god',
#  "upgrdcentre orange customer, may claim free camera phone upgrade loyalty. call 0207 153 9153. offer end 26th july. t&c's apply. opt-out available",
#  "sorry, i'll call later ok bye",
#  'ok way railway',
#  'great princess! love giving receiving oral. doggy style fave position. you? enjoy making love &lt;#&gt; time per night :)',
#  'put stuff road keep getting slippery there?',
#  'going ride bike?',
#  "yup, need. i'll jus wait 4 e rain 2 stop.",
#  'many company. tell language.',
#  'okmail: dear dave final notice collect 4* tenerife holiday #5000 cash award! call 09061743806 landline. tc sae box326 cw25wx 150ppm',
#  'long since screamed, princess?',
#  'nothing. meant money enters account here, bank remove flat rate. someone transfered &lt;#&gt; account &lt;#&gt; dollar got removed. bank differ charge also differ.be sure trust 9ja person sending account detail cos...',
#  "want 2 get laid tonight? want real dogging location sent direct 2 ur mob? join uk's largest dogging network txting moan 69888nyt. ec2a. 31p.msg@150p",
#  'nice line said broken heart- plz cum 1 time infront me... wise trust u... good 9t:)',
#  "ok i'm gonna head usf like fifteen minute",
#  'love aathi..love u lot..',
#  'tension ah?what machi?any problem?',
#  'k, pick another 8th done?',
#  "when're guy getting back? g said thinking staying mcr",
#  'almost there, see u sec',
#  'yo carlos, friend already asking you, working weekend?',
#  'watching tv lor...',
#  'thank baby! cant wait taste real thing...',
#  'change fb jaykwon thuglyfe falconerf',
#  'win really 1 side long time.',
#  'free message activate 500 free text message replying message word free term & conditions, visit www.07781482378.com',
#  'dear reached railway. happen',
#  'depends quality. want type sent boye, faded glory, 6. want ralphs maybe 2',
#  "think i've fixed send test message?",
#  "sorry man account's dry would, want could trade back half could buy shit credit card",
#  'congrats! 1 year special cinema pas 2 yours. call 09061209465 now! c suprman v, matrix3, starwars3, etc 4 free! bx420-ip4-5we. 150pm. dont miss out!',
#  "sorry,in meeting i'll call later",
#  'class &lt;#&gt; reunion?',
#  'free now?can call now?',
#  'got meh... when?',
#  'nope... think go monday... sorry replied late',
#  'told accenture confirm. true.',
#  'kate jackson rec center 7ish, right?',
#  'dear reache room',
#  'fighting world easy, u either win lose bt fightng some1 close u dificult u lose - u lose u win - u still lose.',
#  'ü come out?',
#  'check nuerologist.',
#  'lolnice. went fish ..water.?',
#  "+123 congratulation - week's competition draw u £1450 prize claim call 09050002311 b4280703. t&cs/stop sm 08718727868. 18 150ppm",
#  "waiting e car dat's bored wat. co wait outside got nothing 2 do. home stuff watch tv wat.",
#  'maybe westshore hyde park village, place near house?',
#  "know now. how's anthony. bringing money. i've school fee pay rent stuff like that. thats need help. friend need....|",
#  "what's significance?",
#  'opinion me? 1. 2. jada 3. kusruthi 4. lovable 5. silent 6. spl character 7. matured 8. stylish 9. simple pls reply..',
#  "8 latest, g's still scrounge ammo want give new ak try",
#  "prabha..i'm soryda..realy..frm heart i'm sory",
#  'lol ok forgiven :)',
#  'no..jst change tat only..',
#  'guaranteed latest nokia phone, 40gb ipod mp3 player £500 prize! txt word: collect no: 83355! ibhltd ldnw15h 150p/mtmsgrcvd18+',
#  's:)no competition him.',
#  'boltblue tone 150p reply poly# mono# eg poly3 1. cha cha slide 2. yeah 3. slow jamz 6. toxic 8. come stop 4 tone txt',
#  'credit topped http://www.bubbletext.com renewal pin tgxxrz',
#  'way transport le problematic sat night. way, u want ask n join bday, feel free. need know definite no booking fri.',
#  "usually person unconscious that's child adult may behave abnormally. i.ll call",
#  "that's ebay might le elsewhere.",
#  'shall come get pickle',
#  'gonna go get taco',
#  "that's rude, campus?",
#  'urgent!: mobile no. awarded £2,000 bonus caller prize 02/09/03! 2nd attempt contact you! call 0871-872-9755 box95qu',
#  "hi b ard 4 christmas. enjoy n merry x'mas.",
#  "today's offer! claim ur £150 worth discount vouchers! text yes 85023 now! savamob, member offer mobile! c 08717898035. £3.00 sub. 16 . unsub reply x",
#  'yes! pretty lady like single?',
#  'recieve tone within next 24hrs. term condition please see channel u teletext pg 750',
#  'jay say double-faggot',
#  'private! 2003 account statement 07815296484 show 800 un-redeemed s.i.m. points. call 08718738001 identifier code 41782 expires 18/11/04',
#  'today-sunday..sunday holiday..so work..',
#  'gudnite....tc...practice going',
#  "i'll late...",
#  "i've called while. hoping l8r malaria know miss guys. miss ban big, pls give love especially. great day.",
#  'good afternoon, love! go day ? hope maybe got lead job. think you, boytoy send passionate kiss across sea',
#  'probably gonna while, see later tonight &lt;)',
#  'maybe fat finger press button know do.',
#  'ummmmmaah many many happy return day dear sweet heart.. happy birthday dear',
#  'tirupur da, started office call me.',
#  'www.applausestore.com monthlysubscription@50p/msg max6/month t&csc web age16 2stop txt stop',
#  "famous quote : develop ability listen 'anything' unconditionally without losing temper self confidence, mean ......... 'married'",
#  'going college pa. do. else ill come self. pa.',
#  '4 oclock mine. bash flat plan.',
#  'girl stay bed. girl need recovery time. id rather pas fun cooped bed',
#  'special there?',
#  "know need get hotel now. got invitation apologise. cali sweet come english bloke's weddin",
#  'sorry took long, omw',
#  'wait &lt;#&gt; min..',
#  'ok give 5 minute think see her. btw alibi. cutting hair whole time.',
#  'imagine finally get sink bath put paces, maybe even eat left ... also imagine feel cage cock surrounded bath water, reminding always owns ... enjoy, cuck',
#  "hurry up, i've weed-deficient like three day",
#  'sure, get acknowledgement astoundingly tactless generally faggy demand blood oath fo',
#  'ok. every night take warm bath drink cup milk see work magic. still need loose weight. know',
#  'i‘ll look frying pan case it‘s cheap book perhaps. that‘s silly frying pan isn‘t likely book',
#  'o. well uv cause mutations. sunscreen like essential thesedays',
#  'lunch:)you online?why?',
#  'know friend already told that.',
#  'hi princess! thank pics. pretty. you?',
#  'aiyo... u always c ex one... dunno abt mei, reply... first time u reply fast... lucky workin huh, got bao ur sugardad ah...gee..',
#  "hi msg me:)i'm office..",
#  'thanx 4 e brownie v nice...',
#  'geeeee ... love much barely stand',
#  'gent! trying contact you. last weekend draw show £1000 prize guaranteed. call 09064012160. claim code k52. valid 12hrs only. 150ppm',
#  "fuck babe ... miss already, know ? can't let send money towards net ? need ... want ... crave ...",
#  'ill call u 2mrw ninish, address icky american freek wont stop callin 2 bad jen k eh?',
#  'oooh bed ridden ey? thinking of?',
#  'anyways, go gym whatever, love *smiles* hope ok good day babe ... miss much already',
#  'love it! daddy make scream pleasure! going slap as dick!',
#  'wot u wanna missy?',
#  'yar lor wait 4 mum 2 finish sch lunch lor... whole morning stay home clean room room quite clean... hee...',
#  'know lab goggles went',
#  'open door?',
#  'waiting call.',
#  'nope waiting sch 4 daddy...',
#  '?1,000 cash ?2,000 prize! claim, call09050000327',
#  "i'm tired arguing week week. want on, i'll same.",
#  'ü wait 4 sch finish ard 5..',
#  'mobile number £5000, claim call u back ring claim hot line 09050005321.',
#  'arngd marriage u r walkin unfortuntly snake bite u. bt love marriage dancing frnt snake &amp; sayin bite me, bite me.',
#  'huh early.. ü dinner outside izzit?',
#  'ok anyway need change said',
#  'tried contact reply offer 750 min 150 textand new video phone call 08002988890 reply free delivery tomorrow',
#  'ex-wife able kids. want kid one day?',
#  "how's scotland. hope showing jjc tendencies. take care. live dream",
#  'tell u headache want use 1 hour sick time.',
#  "dun thk i'll quit yet... hmmm, go jazz ? yogasana oso can... go meet em lesson den...",
#  'pete please ring meive hardly gotany credit',
#  'ya srsly better yi tho',
#  "i'm meeting, call later",
#  "ur chance win £250 wkly shopping spree txt: shop 80878. t's&c's www.txt-2-shop.com custcare 08715705022, 1x150p/wk",
#  'specially selected receive 2000 pound award! call 08712402050 line close. cost 10ppm. 16+. t&cs apply. ag promo',
#  'private! 2003 account statement 07753741225 show 800 un-redeemed s. i. m. points. call 08715203677 identifier code: 42478 expires 24/10/04',
#  'still grand prix?',
#  'met stranger choose friend. long world stands, friendship never ends. let friend forever!!! gud nitz...',
#  'great! you?',
#  'gud mrng dear nice day',
#  'important customer service announcement. call freephone 0800 542 0825 now!',
#  'do. exhausted train morning. much wine pie. sleep well',
#  "i'm going buy mum's present ar.",
#  'mind blastin.. tsunami occur on.. rajnikant stopped swimming indian ocean..:-d',
#  "u sending home first ok lor. i'm ready yet.",
#  'speaking cash yet?',
#  'happy there. come noon',
#  'meet lunch la...',
#  'take care n get well soon',
#  'xclusive@clubsaisai 2morow 28/5 soiree speciale zouk nichols paris.free rose 2 lady !!! info: 07946746291/07880867867',
#  'meant say cant wait see u getting bored bridgwater banter',
#  'neva mind ok..',
#  'fine, imma get drink somethin. want come find you?',
#  '22 day kick off! euro2004 u kept date latest news result daily. removed send get txt stop 83222',
#  'valentine game. . . send dis msg ur friends. .. 5 answer r someone really love u. ques- colour suit best?rply',
#  'many dependent',
#  'thanx4 today cer nice 2 catch ave 2 find time often oh well take care c u soon.c',
#  'called said him:)then choose future.',
#  'happy valentine day know early hundred handsomes beauty wish. thought finish aunty uncle 1st...',
#  'like v shock leh. co telling shuhui like telling leona also. like dat almost know liao. got ask abt ur reaction lor.',
#  'family happiness..',
#  'come n pick ü up... come immediately aft ur lesson...',
#  'let snow. let snow. kind weather brings ppl together friendship grow.',
#  'dear got &lt;#&gt; dollar hi hi',
#  'good words.... word may leave u dismay many times.',
#  'make sure alex know birthday fifteen minute far concerned',
#  'sorry, no, got thing do. may pub later.',
#  "nah straight, bring bud drink something that's actually little useful straight cash",
#  "haha good hear, i'm officially paid market 8th",
#  'many lick take get center tootsie pop?',
#  'yup thk r e teacher said make face look longer. darren ask 2 cut short.',
#  'new textbuddy chat 2 horny guy ur area 4 25p free 2 receive search postcode gaytextbuddy.com. txt one name 89693',
#  'today vodafone number ending 4882 selected receive £350 award. number match call 09064019014 receive £350 award.',
#  'please dont say like that. hi hi hi',
#  'thank u!',
#  'oh forwarded message. thought send',
#  'got it. seventeen pound seven hundred ml – hope ok.',
#  'dear voucher holder, 2 claim week offer, pc go http://www.e-tlp.co.uk/expressoffer ts&cs apply.2 stop text txt stop 80062.',
#  'n funny...',
#  'sweetheart, hope kind day! one load reason smile. biola',
#  'ü login dat time... dad fetching ü home now?',
#  'shower, baby?',
#  'askd u question hour before. answer',
#  "well imma definitely need restock thanksgiving, i'll let know i'm",
#  "said kiss, kiss, can't sound effects! gorgeous man he! kind person need smile brighten day!",
#  'probably gonna swing wee bit',
#  'ya nice. . .be ready thursday',
#  'allo! braved bus taken train triumphed. mean we‘re b‘ham. jolly good rest week',
#  'watching cartoon, listening music &amp; eve go temple &amp; church.. u?',
#  'mind ask happened? dont say uncomfortable.',
#  'private! 2003 account statement show 800 un-redeemed s. i. m. points. call 08715203694 identifier code: 40533 expires 31/10/04',
#  'prob. send email.',
#  '?1,000 cash ?2,000 prize! claim, call09050000327. t&c: rstm, sw7 3ss. 150ppm',
#  'thats cool! sometimes slow gentle. sonetimes rough hard :)',
#  "i'm gonna say no. sorry. would normal starting panic time. sorry again! seeing tuesday?",
#  'wait, know wesley town? bet hella drugs!',
#  'fine miss much.',
#  'u got person story',
#  "tell drug dealer's getting impatient",
#  'sun cant come earth send luv rays. cloud cant come river send luv rain. cant come meet u, send care msg u. gud evng',
#  'place man',
#  'doesnt make sense take unless free. need know more, wikipedia.com',
#  '88800 89034 premium phone service call 08718711108',
#  "sea, lay rock. rock, envelope. envelope, paper. paper, 3 words... '",
#  "mum's repent how?",
#  'sorry going home first... daddy come fetch ü later...',
#  'leave de:-). start prepare next:-)..',
#  'yes baby! study position kama sutra ;)',
#  'en chikku nange bakra msg kalstiya..then tea/coffee?',
#  "carlos'll minute still need buy",
#  'pay &lt;decimal&gt; lakhs:)',
#  'good evening! ttyl',
#  'u receive msg?',
#  'ho ho - big belly laugh! see ya tomo',
#  'sms. ac sun0819 post hello:"you seem cool, wanted say hi. hi!!!" stop? send stop 62468',
#  'get ur 1st ringtone free now! reply msg tone. gr8 top 20 tone phone every week £1.50 per wk 2 opt send stop 08452810071 16',
#  "ditto. worry saying anything anymore. like said last night, whatever want i'll same. peace.",
#  "i've got &lt;#&gt; , way could pick up?",
#  'dont knw pa, drink milk..',
#  'maybe?! say hi find got card. great escape wetherspoons?',
#  "piggy, r u awake? bet u're still sleeping. i'm going 4 lunch now...",
#  "cause i'm freaky lol",
#  "missed call cause yelling scrappy. miss u. can't wait u come home. i'm lonely today.",
#  "'hex' place talk of? explain!",
#  'ü log 4 wat. sdryb8i',
#  'xy going 4 e lunch?',
#  "hi i'm sue. 20 year old work lapdancer. love sex. text live - i'm bedroom now. text sue 89555. textoperator g2 1da 150ppmsg 18+",
#  'wanted ask ü wait 4 finish lect. co lect finish hour anyway.',
#  'finished work yet? :)',
#  'every king cry baby every great building map.. imprtant u r today, u wil reach tomorw. gud ni8',
#  'dear,me cherthala.in case u r coming cochin pls call bfore u start.i shall also reach accordingly.or tell day u r coming.tmorow engaged an holiday.',
#  'thanks love. torch bold.',
#  '<forwarded 448712404000>please call 08712404000 immediately urgent message waiting you.',
#  'farm open?',
#  'sorry trouble u again. buy 4d dad again? 1405, 1680, 1843. 2 big 1 small, sat n sun. thanx.',
#  'sister law, hope great month. saying hey. abiola',
#  'purchase stuff today mail you. po box number?',
#  'ah poop. look like ill prob send laptop get fixed cuz gpu problem',
#  'good. good job. like entrepreneur',
#  "aight, close still around alex's place?",
#  'meet corporation st outside gap … see mind working!',
#  'mum ask ü buy food home...',
#  'k..u also dont msg reply msg..',
#  'much r ü willing pay?',
#  "sorry, i'll call later",
#  'important prevent dehydration giving enough fluid',
#  'thats bit weird, even ?- supposed happening? good idea, sure pub!',
#  "true dear..i sat pray evening felt so.so sms'd time...",
#  'think get away trek long family town, sorry',
#  'wanna gym harri',
#  'quite late lar... ard 12 anyway wun b drivin...',
#  'review keep fantastic nokia n-gage game deck club nokia, go 2 www.cnupdates.com/newsletter. unsubscribe alert reply word',
#  '4mths half price orange line rental & latest camera phone 4 free. phone 11mths+? call mobilesdirect free 08000938767 update now! or2stoptxt t&cs',
#  'height confidence: aeronautics professor wer calld &amp; wer askd 2 sit aeroplane. aftr sat wer told dat plane w made students. dey hurried plane.. bt 1 didnt move... said:"if made students,this wont even start........ datz confidence..',
#  'seems like weird timing night g want come smoke day shitstorm attributed always coming making everyone smoke',
#  '08714712388 10am-7pm cost 10p',
#  'save stress. person dorm account, send account detail money sent you.',
#  'also know lunch menu da. . know',
#  'stuff sell i.ll tell',
#  '+449071512431 urgent! 2nd attempt contact u!u £1250 call 09071512433 b4 050703 t&csbcm4235wc1n3xx. callcost 150ppm mobilesvary. max£7. 50',
#  "book lesson? msg me... call work sth... i'm going get specs. membership px3748",
#  'guaranteed £1000 cash £2000 prize. claim yr prize call customer service representative 08714712394 10am-7pm',
#  'macha dont feel upset.i assume mindset.believe one evening wonderful plan us.let life begin again.call anytime',
#  'oh it? send address',
#  "s'fine. anytime. best it.",
#  'wondar full flim.',
#  'ya even cooky jelly',
#  'world running still.maybe feeling same,so it.or admit,i mad.then correction?or let call life.and keep running world,may u r also running.lets run.',
#  'got it! look scrumptious... daddy want eat night long!',
#  "co lar i'm ba dao ok... 1 pm lor... u never ask go ah... said u would ask fri said u ask today...",
#  'alright omw, gotta change order half8th',
#  'exactly. anyways far. jide study visiting',
#  'dunno u ask me.',
#  'email alertfrom: jeri stewartsize: 2kbsubject: low-cost prescripiton drvgsto listen email call 123',
#  "didn't. spring coming early yay!",
#  'lol feel bad use money take steak dinner =d',
#  'even u dont get trouble convincing..just tel twice tel neglect msg dont c read it..just dont reply',
#  'leaving qatar tonite search opportunity.all went fast.pls add ur prayer dear.rakhesh',
#  'one talking',
#  'thanks looking me. really appreciate.',
#  'hi. customer loyalty offer:the new nokia6650 mobile £10 txtauction! txt word: start no: 81151 & get now! 4t&ctxt tc 150p/mtmsg',
#  'wish now!',
#  "haha mayb u're rite... u know well. da feeling liked someone gd lor. u faster go find one gal group attached liao.",
#  'yes there. glad made it.',
#  'well :)all little time. thing good time ahead:',
# ...
#  "i'm nt goin, got somethin on, unless meetin 4 dinner lor... haha, wonder go ti time...",
#  "sorry, i'll call later",
#  'cant pick phone right now. pls send message',
#  "lol know! they're dramatic. school already closed tomorrow. apparently can't drive inch snow supposed get.",
#  'getting anywhere damn job hunting here!',
#  'lol! u drunkard! hair moment. yeah still 4 tonight. wats plan?',
#  'idc get here, weaseling way shit twice row',
#  'wil &lt;#&gt; minutes. got space',
#  'sleeping..and surfing',
#  'thanks picking trash.',
#  'go tell friend sure want live smoke much spend hour begging come smoke',
#  'hi kate lovely see tonight ill phone tomorrow. got sing guy gave card! xxx',
#  'happy new year dear brother. really miss you. got number decided send text wishing happiness. abiola',
#  'mean get door',
#  'opinion me? 1. 2. jada 3. kusruthi 4. lovable 5. silent 6. spl character 7. matured 8. stylish 9. simple pls reply..',
#  'hmmm ... thought said 2 hour slave, 3 ... late ... punish ?',
#  'beerage?',
#  'important customer service announcement premier. call freephone 0800 542 0578 now!',
#  'dont think so. turn like randomlly within 5min opening',
#  'supposed make it, still town though',
#  'own. time fix spelling. sometimes get completely diff word. go figure',
#  'ever thought living good life perfect partner? txt back name age join mobile community. (100p/sms)',
#  '5 free top polyphonic tone call 087018728737, national rate. get toppoly tune sent every week, text subpoly 81618, £3 per pole. unsub 08718727870.',
#  'gud mrng dear hav nice day',
#  "hoping enjoyed game yesterday. sorry i've touch pls know fondly bein thot off. great week. abiola",
#  'e best 4 ur driving tmr :-)',
#  'y?where u dogbreath? sounding like jan c that\x92s al!!!!!!!!!',
#  'omg want scream. weighed lost weight! woohoo!',
#  'generally one. uncountable noun - u dictionary. piece research?',
#  'really getting hanging around.',
#  "orange customer, may claim free camera phone upgrade loyalty. call 0207 153 9996. offer end 14thmarch. t&c's apply. opt-out availa",
#  'petey boy whereare friendsare thekingshead come canlove nic',
#  'ok msg u b4 leave house.',
#  'gimme &lt;#&gt; minute ago',
#  'last chance! claim ur £150 worth discount voucher today! text shop 85023 now! savamob, offer mobile! c savamob pobox84, m263uz. £3.00 sub. 16',
#  'appt &lt;time&gt; am. fault u listen. told u twice',
#  'free 1st week! no1 nokia tone 4 ur mobile every week txt nokia 8077 get txting tell ur mates. www.getzed.co.uk pobox 36504 w45wq 16+ norm150p/tone',
#  'guaranteed £200 award even £1000 cashto claim ur award call free 08000407165 (18+) 2 stop getstop 88222 php. rg21 4jx',
#  "k i'll 4.",
#  'dled 3d imp',
#  "sure, make sure know ain't smokin yet",
#  'boooo always work. quit.',
#  'taking half day leave bec well',
#  'ugh wanna get bed. warm.',
#  's:)s.nervous &lt;#&gt; :)',
#  "there's ring come guy costumes. gift future yowifes. hint hint",
#  'congratulation ur awarded either £500 cd gift voucher & free entry 2 £100 weekly draw txt music 87066 tncs www.ldew.com1win150ppmx3age16',
#  'borrow ur bag ok.',
#  'u outbid simonwatson5120 shinco dvd plyr. 2 bid again, visit sms. ac/smsrewards 2 end bid notifications, reply end',
#  "where's boytoy? miss ... happened?",
#  "lot used one babe, model help. youi bring he'll match",
#  'also bringing galileo dobby',
#  'responding',
#  'boo babe! u enjoyin yourjob? u seemed 2 b gettin well hunny!hope ure ok?take care & i\x92llspeak 2u soonlots loveme xxxx.',
#  "good afternoon starshine! how's boytoy? crave yet? ache fuck ? *sips cappuccino* miss babe *teasing kiss*",
#  'road cant txt',
#  'smsservices. yourinclusive text credits, pls goto www.comuk.net login= 3qxj9 unsubscribe stop, extra charge. help 08702840625.comuk. 220-cm2 9ae',
#  "25p 4 alfie moon's child need song ur mob. tell ur m8s. txt tone charity 8007 nokias poly charity polys: zed 08701417012 profit 2 charity.",
#  'good evening! ttyl',
#  'hmm .. bit piece lol ... *sighs* ...',
#  'hahaha..use brain dear',
#  'hey. got mail?',
#  'sorry light turned green, meant another friend wanted &lt;#&gt; worth may around',
#  'thanks yesterday sir. wonderful. hope enjoyed burial. mojibiola',
#  'u secret admirer. reveal think u r special. call 09065174042. opt reply reveal stop. 1.50 per msg recd. cust care 07821230901',
#  'hi mate rv u hav nice hol message 3 say hello coz haven\x92t sent u 1 age started driving stay roads!rvx',
#  'dear voucher holder, claim week offer, pc please go http://www.e-tlp.co.uk/expressoffer ts&cs apply. stop texts, txt stop 80062',
#  "thank much. skyped wit kz sura, didnt get pleasure company. hope good. we've given ultimatum oh! countin aburo. enjoy! message sent day ago",
#  'surely result offer:)',
#  'good morning dear........... great &amp; successful day.',
#  'want 750 anytime network min 150 text new video phone five pound per week call 08002888812 reply delivery tomorrow',
#  "sir, late paying rent past month pay $ &lt;#&gt; charge. felt would inconsiderate nag something give great cost that's didnt speak up. however recession wont able pay charge month hence askin well ahead month's end. please help. thanks",
#  'tried contact offer new video phone 750 anytime network min half price rental camcorder call 08000930705 reply delivery wed',
#  'last chance 2 claim ur £150 worth discount vouchers-text yes 85023 now!savamob-member offer mobile c 08717898035. £3.00 sub. 16 . remove txt x stop',
#  'luv u soo much u don\x92t understand special u r 2 ring u 2morrow luv u xxx',
#  "pls send comprehensive mail i'm paying, much.",
#  "prashanthettan's mother passed away last night. pray family.",
#  'urgent! call 09066350750 landline. complimentary 4* ibiza holiday 10,000 cash await collection sae t&cs po box 434 sk3 8wp 150 ppm 18+',
#  'k.k:)when going?',
#  "meanwhile shit suite: xavier decided give u &lt;#&gt; second warning samantha coming playing jay's guitar impress shit. also think doug realizes live anymore",
#  "stomach thru much trauma swear can't eat. better lose weight.",
#  'office:)whats matter..msg now.i call break:).',
#  "yeah there's barely enough room two us, x many fucking shoes. sorry man, see later",
#  "today's offer! claim ur £150 worth discount vouchers! text yes 85023 now! savamob, member offer mobile! c 08717898035. £3.00 sub. 16 . unsub reply x",
#  'u reach orchard already? u wan 2 go buy ticket first?',
#  'real, baby! want bring inner tigress...',
#  'da run activate full version da.',
#  'ah poor baby!hope urfeeling bettersn luv! probthat overdose work hey go careful spk 2 u sn lot lovejen xxx.',
#  "stop story. i've told i've returned he's saying order it.",
#  'talk sexy!! make new friend fall love world discreet text dating service. text vip 83110 see could meet.',
#  'going take babe ?',
#  'hai ana tomarrow coming morning. &lt;decimal&gt; ill sathy go rto office. reply came home.',
#  'spoon okay?',
#  'say somebody named tampa',
#  'work now. going min.',
#  'brother genius',
#  "sorry, guess whenever get hold connections, maybe hour two? i'll text",
#  'u find time bus coz need sort stuff out.',
#  'dude ive seeing lotta corvette lately',
#  'congratulation ur awarded either yr supply cd virgin record mystery gift guaranteed call 09061104283 ts&cs www.smsco.net £1.50pm approx 3mins',
#  'here, consider wall bunker shit important never play peaceful guess place high enough matter',
#  'private! 2003 account statement 07808 xxxxxx show 800 un-redeemed s. i. m. points. call 08719899217 identifier code: 41685 expires 07/11/04',
#  'hello. need posh bird chap user trial prod champneys. put down? need address dob asap. ta r',
#  'u want xmas? 100 free text message & new video phone half price line rental? call free 0800 0721072 find more!',
#  'well officially philosophical hole, u wanna call home ready saved!',
#  'going good...no problem..but still need little experience understand american customer voice...',
#  "i'll text drop x",
#  "ugh long day. i'm exhausted. want cuddle take nap",
#  'talk atleast day...!!! otherwise miss best friend world...!!! -shakespeare- shesil &lt;#&gt;',
#  'shop till u drop, you, either 10k, 5k, £500 cash £100 travel voucher, call now, 09064011000. ntt po box cr01327bt fixedline cost 150ppm mobile vary',
#  'castor? need see something',
#  'sunshine quiz wkly q! win top sony dvd player u know country liverpool played mid week? txt ansr 82277. £1.50 sp:tyrone',
#  'u secret admirer looking 2 make contact u-find r*reveal think ur special-call 09058094565',
#  'u secret admirer looking 2 make contact u-find r*reveal think ur special-call 09065171142-stopsms-08',
#  'reminder: downloaded content already paid for. goto http://doit. mymoby. tv/ collect content.',
#  "see, knew giving break time woul lead always wanting miss curfew. gonna gibe 'til one, midnight movie gonna get til 2. need come home. need getsleep and, anything, need b studdying ear training.",
#  'love give massages. use lot baby oil... fave position?',
#  'dude go sup',
#  'yoyyooo u know change permission drive mac. usb flash drive',
#  'gibbs unsold.mike hussey',
#  'like talk pa able to. dont know y.',
#  'dun cut short leh. u dun like ah? failed. quite sad.',
#  'unbelievable faglord',
#  'wife.how knew time murder exactly',
#  'ask princess?',
#  'great princess! thinking me? :)',
#  'nutter. cutter. ctter. cttergg. cttargg. ctargg. ctagg. ie',
#  "ok noe u're busy i'm really bored msg u. oso dunno wat colour choose 4 one.",
#  'g class early tomorrow thus trying smoke &lt;#&gt;',
#  'superb thought- "be grateful u dont everything u want. mean u still opportunity happier tomorrow u today.":-)',
#  'hope good week. checking',
#  "i'm used it. hope agent drop since i've booked thing year. whole boston, nyc experiment.",
#  "thursday night? yeah, sure thing, we'll work",
#  'free ringtone waiting collected. simply text password "mix" 85069 verify. get usher britney. fml, po box 5249, mk17 92h. 450ppw 16',
#  'probably money worries. thing coming due several outstanding invoice work two three month ago.',
#  'possible teach you. where.',
#  'wonder phone battery went dead ? tell you, love babe',
#  "lovely smell bus ain't tobacco...",
#  "we're getting worried here, derek taylor already assumed worst",
#  "hey what's charles sorry late reply.",
#  'lastest stereophonics, marley, dizzee racal, libertine strokes! win nookii game flirt!! click themob wap bookmark text wap 82468',
#  'i.ll give it. plus said grinule greet whenever speak',
#  'white fudge oreo store',
#  'january male sale! hot gay chat cheaper, call 08709222922. national rate 1.5p/min cheap 7.8p/min peak! stop text call 08712460324 (10p/min)',
#  "love ! come took long leave zaher's? got word ym happy see sad left. miss",
#  'sorry hurt you.',
#  "can't. feel nauseous. i'm pissed. eat sweet week cause today planning pig out. dieting week. i'm hungry :/",
#  'ok lor early. still project meeting now.',
#  'call da, waiting call.',
#  'could ask carlos could get anybody else chip',
#  'actually send reminder today. wonderful weekend',
#  "people see msgs, think iam addicted msging... wrong, bcoz don\\'t know iam addicted sweet friends..!! bslvyl",
#  'hey gave photo registered driving ah? tmr wanna meet yck?',
#  'dont talk ever ok word.',
#  'u wana see',
#  "way school. pls send ashley's number",
#  'shall fine. avalarr now. hollalater',
#  "went attend another two round today..but still did't reach home..",
#  'actually deleted old website..now blogging magicalsongs.blogspot.com',
#  'k, wait chikku..il send aftr &lt;#&gt; min',
#  "i'm diet. ate 1 many slice pizza yesterday. ugh i'm always diet.",
#  'k:)i give kvb acc details:)',
#  'oh come ah?',
#  'money!!! r lucky winner ! 2 claim prize text money 2 88600 £1million give away ! ppt150x3+normal text rate box403 w1t1jy',
#  "i'm really sorry b able 2 friday.hope u find alternative.hope yr term's going ok:-)",
#  'congratulation ore mo owo wa. enjoy wish many happy moment fro wherever go',
#  'samus shoulder yet',
#  'time think it? need know near campus',
#  'dear matthew please call 09063440451 landline, complimentary 4*lux tenerife holiday £1000 cash await collection. ppm150 sae t&cs box334 sk38xh.',
#  'dun wear jean lor...',
#  'since when, side, fever, vomitin.',
#  'k:)k.are college?',
#  'urgent! call 09061749602 landline. complimentary 4* tenerife holiday £10,000 cash await collection sae t&cs box 528 hp20 1yf 150ppm 18+',
#  'better. made friday stuffed like pig yesterday. feel bleh. least writhing pain kind bleh.',
#  "sell we'll ton coins. sell coin someone thru paypal. voila! money back life pockets:)",
#  'theyre lot places. hospital medical place safe.',
#  'getting touch folk waiting company? txt back name age opt in! enjoy community (150p/sms)',
#  "also i've sorta blown couple time recently id rather text blue looking weed",
#  'sent score sophas secondary application schools. think thinking applying, research cost also. contact joke ogunrinde, school one le expensive one',
#  'cant wait see you! photo useful? :)',
#  'ur cash-balance currently 500 pound - maximize ur cash-in send go 86688 150p/msg. cc: 08718720201 po box 114/14 tcr/w1',
#  'hey booked kb sat already... lesson going ah? keep sat night free need meet confirm lodging',
#  'chk ur belovd m dict',
#  'time want come?',
#  'awesome, lemme know whenever around',
#  'shb b ok lor... thanx...',
#  'beautiful truth gravity.. read carefully: "our heart feel light someone it.. feel heavy someone leaf it.." good night',
#  "also remember get dobby's bowl car",
#  'filthy story girl waiting',
#  "sorry c ur msg... yar lor poor thing... 4 one night... tmr u'll brand new room 2 sleep in...",
#  'love decision, feeling. could decide love, then, life would much simpler, le magical',
#  'welp apparently retired',
#  "sort code acc . bank natwest. reply confirm i've sent right person!",
#  '@',
#  "u sure u can't take sick time?",
#  'urgent! trying contact u. today draw show £800 prize guaranteed. call 09050001808 land line. claim m95. valid12hrs',
#  'watching cartoon, listening music &amp; eve go temple &amp; church.. u?',
#  'yo chad gymnastics class wanna take? site say christian class full..',
#  'much buzy',
#  'better still catch let ask sell &lt;#&gt; me.',
#  'sure night menu. . . know noon menu',
#  'u want come back?.a beautiful necklace token heart you.thats give wife liking.be see..no one give that.dont call me.i wait till come.',
#  'willing go aptitude class.',
#  'wont b 2.15 trying 2 sort house out, ok?',
#  'yar lor wan 2 go c horse racing today mah, eat earlier lor. ate chicken rice. u?',
#  'haha awesome, omw back',
#  'yup thk e shop close lor.',
#  'account number?',
#  'eh u send wrongly lar...',
#  'hey ad crap nite borin without ya 2 boggy u boring biatch! thanx u wait til nxt time il ave ya',
#  'ok shall talk',
#  'dont hesitate. know second time weakness like that. keep notebook eat day anything changed day sure nothing',
#  'hey pay. salary de. &lt;#&gt; .',
#  'another month. need chocolate weed alcohol.',
#  'started searching get job days.he great potential talent.',
#  'reckon need town eightish walk * carpark.',
#  'congrats! 2 mobile 3g videophones r yours. call 09063458130 now! videochat wid mates, play java games, dload polyph music, noline rentl.',
#  'look fuckin time. fuck think',
#  'yo guess dropped',
#  "carlos say he'll mu &lt;#&gt; minute",
#  "i'm office . call &lt;#&gt; min:)",
#  "geeee ... miss already, know ? think about. fuck, can't wait till next year together ... *loving kiss*",
#  'yun ah.the ubi one say ü wan call tomorrow.call 67441233 look irene.ere got bus8,22,65,61,66,382. ubi cres,ubi tech park.6ph 1st 5wkg days.èn',
#  'ugh. gotta drive back sd la. butt sore.',
#  '26th july',
#  'hi im relaxing time ever! get 7am every day! party good night? get home tomorrow 5ish.',
#  'ü... ü wan come come lor... din c stripe skirt...',
#  'xmas story peace.. xmas msg love.. xmas miracle jesus.. hav blessed month ahead &amp; wish u merry xmas...',
#  "can't, number!",
#  'change again... e one next escalator...',
#  "yetunde i'm class run water make ok. pls now.",
#  'lot happened here. feel quiet. beth aunt charlie working lots. helen mo. been?',
#  'ü wait 4 bus stop aft ur lect lar. dun c ü go get car come back n pick ü.',
#  ...]

# %%
Y = pd.get_dummies(messages['label'], dtype=int)
Y
# Out:
#       ham  spam
# 0       1     0
# 1       1     0
# 2       0     1
# 3       1     0
# 4       1     0
# ...   ...   ...
# 5567    0     1
# 5568    1     0
# 5569    1     0
# 5570    1     0
# 5571    1     0
#
# [5572 rows x 2 columns]

# %%
Y = Y['spam'].values
Y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
# Test train split
from sklearn.model_selection import train_test_split
X_train, X_test,Y_train,Y_test = train_test_split(corpus, Y, test_size=0.3, random_state=3)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features=2000, ngram_range=(1,2))

# %%
X_train = tfidf.fit_transform(X_train).toarray()
X_test = tfidf.transform(X_test).toarray()

# %%
tfidf.vocabulary_
# Out:
# {'decide': 482,
#  'co': 385,
#  'si': 1541,
#  'going': 729,
#  'home': 832,
#  'liao': 977,
#  'co si': 386,
#  'going home': 730,
#  'heard': 802,
#  'call': 291,
#  'night': 1194,
#  'on': 1251,
#  'make': 1059,
#  'like': 982,
#  'last': 946,
#  'time': 1725,
#  'xx': 1970,
#  'luv': 1052,
#  'net': 1177,
#  'pls': 1332,
#  'enough': 580,
#  'family': 614,
#  'hot': 841,
#  'sun': 1645,
#  'place': 1322,
#  'no': 1199,
#  'reason': 1414,
#  'if': 868,
#  'invited': 888,
#  'actually': 121,
#  'go': 719,
#  'wait': 1853,
#  'serious': 1519,
#  'yup': 1999,
#  'wun': 1965,
#  'believe': 233,
#  'wat': 1874,
#  'really': 1413,
#  'neva': 1180,
#  'msg': 1152,
#  'sent': 1517,
#  'shuhui': 1540,
#  'hi': 815,
#  'always': 151,
#  'online': 1255,
#  'yahoo': 1974,
#  'would': 1961,
#  'chat': 357,
#  'yes': 1984,
#  'he': 798,
#  'great': 755,
#  'told': 1737,
#  'kallis': 916,
#  'best': 234,
#  'world': 1956,
#  'tough': 1754,
#  'get': 699,
#  'out': 1277,
#  'die': 502,
#  'want': 1864,
#  'hey': 812,
#  'horny': 838,
#  'see': 1500,
#  'naked': 1171,
#  'text': 1684,
#  'charged': 355,
#  '150pm': 42,
#  'unsubscribe': 1799,
#  'stop': 1625,
#  'text stop': 1687,
#  'still': 1622,
#  'da': 461,
#  'darlin': 465,
#  'im': 872,
#  'hope': 835,
#  'good': 735,
#  'back': 209,
#  'give': 714,
#  'hi darlin': 816,
#  'hope good': 836,
#  'give call': 715,
#  '11': 27,
#  'then': 1704,
#  'well': 1907,
#  'early': 554,
#  'morning': 1140,
#  'mobile': 1123,
#  'lt': 1042,
#  'gt': 760,
#  'added': 124,
#  'contact': 417,
#  'list': 992,
#  'www': 1966,
#  'fullonsms': 682,
#  'com': 397,
#  'send': 1511,
#  'free': 660,
#  'sm': 1563,
#  'people': 1294,
#  'visit': 1844,
#  'lt gt': 1044,
#  'fullonsms com': 683,
#  'need': 1176,
#  'one': 1252,
#  'happened': 788,
#  'part': 1286,
#  'checking': 362,
#  'what': 1913,
#  'something': 1581,
#  'guy': 776,
#  'know': 930,
#  'about': 113,
#  'won': 1946,
#  'valued': 1832,
#  'customer': 457,
#  'computer': 411,
#  'picked': 1312,
#  'win': 1929,
#  '150': 38,
#  'prize': 1371,
#  'collect': 391,
#  'easy': 556,
#  'easy call': 557,
#  'single': 1550,
#  'line': 988,
#  'big': 237,
#  'meaning': 1082,
#  'miss': 1110,
#  'anything': 167,
#  'ur': 1803,
#  'life': 979,
#  'but': 281,
#  'gud': 769,
#  'nyt': 1232,
#  'gud nyt': 773,
#  'xmas': 1969,
#  '100': 19,
#  'message': 1096,
#  'new': 1182,
#  'video': 1839,
#  'phone': 1305,
#  'half': 784,
#  'price': 1366,
#  'rental': 1431,
#  '0800': 8,
#  'find': 635,
#  'more': 1139,
#  'free text': 667,
#  'new video': 1185,
#  'video phone': 1840,
#  'half price': 785,
#  'price line': 1367,
#  'line rental': 990,
#  'call free': 296,
#  'free 0800': 661,
#  'must': 1166,
#  'dead': 478,
#  'forever': 652,
#  'you': 1992,
#  'na': 1169,
#  'buy': 282,
#  'space': 1599,
#  'chance': 350,
#  'arcade': 176,
#  'game': 688,
#  'press': 1363,
#  'std': 1621,
#  'wap': 1871,
#  'charge': 354,
#  'o2': 1233,
#  'uk': 1789,
#  'games': 689,
#  'term': 1682,
#  'purchase': 1382,
#  'chance win': 351,
#  'co uk': 387,
#  'stuff': 1635,
#  'sell': 1509,
#  'll': 998,
#  'tell': 1675,
#  'll tell': 1004,
#  'ya': 1973,
#  'even': 592,
#  'thank': 1693,
#  'much': 1159,
#  'love': 1032,
#  'wonderful': 1948,
#  'thank you': 1694,
#  'cool': 426,
#  'll text': 1005,
#  'we': 1885,
#  're': 1405,
#  'here': 811,
#  'we re': 1887,
#  'might': 1102,
#  'case': 335,
#  'plan': 1323,
#  'can': 321,
#  'confidence': 413,
#  'money': 1134,
#  'train': 1757,
#  'not': 1216,
#  'staying': 1620,
#  'today': 1733,
#  'around': 179,
#  'wednesday': 1894,
#  'though': 1719,
#  'fancy': 615,
#  'club': 384,
#  'week': 1896,
#  'way': 1882,
#  '350': 71,
#  'award': 201,
#  'number': 1227,
#  'ending': 573,
#  'selected': 1506,
#  'receive': 1416,
#  'match': 1071,
#  'please': 1329,
#  'claim': 373,
#  'code': 388,
#  'rate': 1401,
#  'app': 172,
#  '350 award': 72,
#  'number ending': 1229,
#  'selected receive': 1507,
#  'receive 350': 1418,
#  'please call': 1330,
#  'claim code': 375,
#  'decided': 483,
#  'yet': 1988,
#  'eh': 564,
#  'per': 1295,
#  'request': 1439,
#  'melle': 1090,
#  'oru': 1271,
#  'set': 1524,
#  'callertune': 309,
#  'callers': 307,
#  'copy': 428,
#  'friend': 672,
#  'per request': 1298,
#  'callertune callers': 310,
#  'callers press': 308,
#  'press copy': 1364,
#  'copy friend': 429,
#  'reaching': 1408,
#  'another': 162,
#  'say': 1482,
#  'me': 1079,
#  'jay': 903,
#  'totally': 1752,
#  'fucking': 680,
#  'speak': 1600,
#  'it': 897,
#  'plus': 1338,
#  'said': 1474,
#  'greet': 758,
#  'whenever': 1917,
#  'beautiful': 228,
#  'truth': 1766,
#  'face': 611,
#  'could': 433,
#  'seen': 1505,
#  'everyone': 598,
#  'heart': 803,
#  'loved': 1038,
#  'ni8': 1190,
#  'gud ni8': 772,
#  'maybe': 1078,
#  'wake': 1856,
#  'babe': 207,
#  'kiss': 928,
#  'across': 119,
#  'sea': 1492,
#  'across sea': 120,
#  'pretty': 1365,
#  'late': 950,
#  'lesson': 972,
#  'first': 641,
#  'join': 906,
#  'mrt': 1151,
#  'want go': 1866,
#  'england': 577,
#  'dont': 528,
#  'team': 1672,
#  'news': 1187,
#  'txt': 1778,
#  'national': 1173,
#  '87077': 105,
#  'eg': 562,
#  'try': 1767,
#  '20': 48,
#  '16': 44,
#  'dont miss': 530,
#  'tried': 1760,
#  'calling': 311,
#  'unable': 1794,
#  'reach': 1406,
#  'missed': 1113,
#  'cal': 290,
#  'thinkin': 1714,
#  'goin': 728,
#  've': 1833,
#  'year': 1979,
#  'exam': 603,
#  'we ve': 1888,
#  '2day': 62,
#  'normal': 1215,
#  'this': 1716,
#  'real': 1412,
#  'rest': 1441,
#  'wot': 1960,
#  'lost': 1029,
#  'nah': 1170,
#  'straight': 1630,
#  'bring': 269,
#  'bud': 276,
#  'drink': 541,
#  'that': 1697,
#  'little': 994,
#  'cash': 336,
#  'sorry': 1590,
#  'just': 914,
#  'mite': 1117,
#  'up': 1800,
#  'yeah': 1976,
#  'random': 1400,
#  'dude': 546,
#  'change': 352,
#  'info': 882,
#  'party': 1288,
#  'never': 1181,
#  'study': 1633,
#  'safe': 1473,
#  'thats': 1698,
#  'thats cool': 1699,
#  'done': 527,
#  'internet': 886,
#  'slow': 1561,
#  'later': 951,
#  'thing': 1707,
#  'tomo': 1738,
#  'happen': 787,
#  'dear': 480,
#  'now': 1219,
#  'may': 1076,
#  'mode': 1128,
#  'sha': 1528,
#  'reply': 1433,
#  'send message': 1513,
#  'll get': 1000,
#  'get it': 703,
#  'it reply': 899,
#  'aight': 139,
#  'come': 398,
#  'tonight': 1745,
#  'later tonight': 953,
#  'simple': 1548,
#  'almost': 145,
#  'there': 1705,
#  'spoke': 1609,
#  'uncle': 1795,
#  'john': 905,
#  'feel': 625,
#  'keep': 920,
#  'listen': 993,
#  'promise': 1380,
#  'let': 973,
#  'work': 1953,
#  'long': 1019,
#  'help': 808,
#  'happy': 791,
#  'sunshine': 1648,
#  'quiz': 1393,
#  'wkly': 1942,
#  'top': 1749,
#  'sony': 1586,
#  'dvd': 552,
#  'player': 1328,
#  'country': 434,
#  'in': 876,
#  '82277': 96,
#  '50': 76,
#  'sp': 1598,
#  'sunshine quiz': 1649,
#  'quiz wkly': 1394,
#  'sony dvd': 1587,
#  '82277 50': 97,
#  'bad': 211,
#  'dream': 539,
#  'tho': 1718,
#  'so': 1572,
#  'right': 1449,
#  'didnt': 500,
#  'guess': 774,
#  'final': 632,
#  'attempt': 192,
#  '86688': 102,
#  '150p': 40,
#  'suite342': 1643,
#  '2lands': 63,
#  'row': 1464,
#  'w1j6hl': 1850,
#  'ldn': 959,
#  '18': 45,
#  'yr': 1997,
#  'final attempt': 633,
#  'attempt contact': 193,
#  'txt chat': 1779,
#  'chat 86688': 358,
#  '86688 150p': 103,
#  'suite342 2lands': 1644,
#  '2lands row': 64,
#  'row w1j6hl': 1465,
#  'w1j6hl ldn': 1851,
#  'ah': 137,
#  'look': 1022,
#  'ill': 871,
#  'prob': 1375,
#  'laptop': 942,
#  'problem': 1377,
#  'look like': 1023,
#  'sleep': 1558,
#  'wish': 1933,
#  'day': 472,
#  'full': 681,
#  'feeling': 626,
#  'better': 235,
#  'opportunity': 1264,
#  'thought': 1720,
#  'good morning': 739,
#  'love go': 1034,
#  'great day': 756,
#  'okay': 1246,
#  'meant': 1083,
#  'sound': 1595,
#  'pub': 1381,
#  'whatever': 1914,
#  'saying': 1484,
#  'is': 894,
#  'semester': 1510,
#  'kept': 921,
#  'latest': 954,
#  'result': 1442,
#  'daily': 464,
#  'amt': 155,
#  'think': 1709,
#  'usf': 1824,
#  'asks': 188,
#  'information': 883,
#  'sms': 1568,
#  'pin': 1319,
#  'thru': 1721,
#  'email': 568,
#  'password': 1290,
#  'word': 1951,
#  'ok': 1243,
#  'finish': 639,
#  'pick': 1309,
#  'esplanade': 587,
#  'lor': 1027,
#  'else': 566,
#  'other': 1273,
#  'rcvd': 1404,
#  'hg': 813,
#  'over': 1279,
#  'me send': 1080,
#  '150p msg': 41,
#  'msg rcvd': 1155,
#  'hg suite342': 814,
#  'meet': 1087,
#  'bin': 239,
#  'earth': 555,
#  'sofa': 1573,
#  'hav': 795,
#  'gd': 694,
#  'mate': 1072,
#  'got': 745,
#  'type': 1787,
#  'wan': 1859,
#  'hee': 805,
#  'noe': 1204,
#  'watch': 1877,
#  'ask': 184,
#  'asking': 187,
#  'oso': 1272,
#  'call me': 298,
#  'address': 125,
#  'get free': 701,
#  'free call': 663,
#  'oh': 1241,
#  'brand': 267,
#  'class': 378,
#  'pm': 1340,
#  'coffee': 389,
#  'stay': 1619,
#  'tomorrow': 1739,
#  'lol': 1017,
#  'too': 1747,
#  'secret': 1496,
#  'admirer': 126,
#  'looking': 1025,
#  'reveal': 1444,
#  'special': 1603,
#  'secret admirer': 1497,
#  'admirer looking': 127,
#  'looking make': 1026,
#  'make contact': 1060,
#  'contact find': 418,
#  'find reveal': 637,
#  'reveal think': 1445,
#  'think ur': 1713,
#  'ur special': 1812,
#  'special call': 1604,
#  'coming': 404,
#  'hello': 807,
#  'ive': 901,
#  'finished': 640,
#  'college': 394,
#  'kate': 918,
#  'xxx': 1971,
#  'love kate': 1035,
#  'house': 845,
#  'maid': 1057,
#  'murderer': 1164,
#  'coz': 438,
#  'man': 1064,
#  'murdered': 1162,
#  'th': 1692,
#  'january': 902,
#  'holiday': 828,
#  'closed': 383,
#  'including': 879,
#  'post': 1356,
#  'office': 1239,
#  'understand': 1796,
#  'house maid': 846,
#  'murdered lt': 1163,
#  'gt th': 765,
#  'post office': 1357,
#  'urgent': 1815,
#  'important': 874,
#  'user': 1823,
#  'lucky': 1049,
#  'log': 1012,
#  'onto': 1257,
#  'http': 851,
#  'urawinner': 1813,
#  'fantastic': 617,
#  'surprise': 1657,
#  'awaiting': 199,
#  'important information': 875,
#  'lucky day': 1050,
#  'log onto': 1013,
#  'onto http': 1258,
#  'http www': 852,
#  'www urawinner': 1968,
#  'urawinner com': 1814,
#  'amp': 154,
#  'car': 330,
#  'room': 1460,
#  'll let': 1001,
#  'let know': 975,
#  'sending': 1515,
#  'old': 1248,
#  'wondering': 1949,
#  'intro': 887,
#  'cover': 437,
#  'energy': 574,
#  'abt': 114,
#  'tmr': 1731,
#  'to': 1732,
#  'how': 847,
#  'chikku': 365,
#  'bt': 273,
#  'marriage': 1069,
#  'nt': 1224,
#  'dinner': 510,
#  'dun': 547,
#  'anything lor': 168,
#  'dun wan': 549,
#  'turn': 1773,
#  'didn': 499,
#  'found': 658,
#  'cheap': 359,
#  'advance': 129,
#  'somewhere': 1584,
#  'isnt': 896,
#  'dunno': 550,
#  'juz': 915,
#  'card': 331,
#  'called': 304,
#  'hair': 783,
#  'sense': 1516,
#  'tot': 1751,
#  'cut': 459,
#  'network': 1178,
#  'operator': 1261,
#  'service': 1521,
#  'biz': 243,
#  'okie': 1247,
#  'sat': 1477,
#  'tyler': 1786,
#  'take': 1662,
#  'gonna': 734,
#  'drop': 544,
#  'order': 1268,
#  'got enough': 746,
#  'boytoy': 266,
#  'took': 1748,
#  'leave': 964,
#  'sad': 1470,
#  'left': 967,
#  'she': 1531,
#  'fine': 638,
#  'mine': 1106,
#  'pls send': 1337,
#  'doing': 525,
#  'sleeping': 1559,
#  'thanks': 1695,
#  'fuck': 679,
#  'came': 315,
#  'brother': 271,
#  'next': 1188,
#  'ready': 1411,
#  'new year': 1186,
#  'next week': 1189,
#  'sister': 1553,
#  'waiting': 1854,
#  'expires': 608,
#  '04': 7,
#  'message waiting': 1097,
#  'goodmorning': 742,
#  'decimal': 484,
#  'min': 1103,
#  'lt decimal': 1043,
#  'decimal gt': 485,
#  'gt min': 763,
#  'choose': 369,
#  'quality': 1389,
#  'training': 1758,
#  'one day': 1253,
#  'tone': 1740,
#  'poly': 1349,
#  'ringtones': 1455,
#  'original': 1270,
#  'apply': 173,
#  'rate apply': 1402,
#  'friends': 673,
#  'birthday': 240,
#  'loving': 1041,
#  'ar': 175,
#  'detail': 496,
#  'book': 252,
#  'treat': 1759,
#  'today birthday': 1734,
#  'road': 1457,
#  'touch': 1753,
#  'weekend': 1900,
#  'we ll': 1886,
#  'good week': 741,
#  'close': 382,
#  'away': 204,
#  'plz': 1339,
#  'yo': 1990,
#  'wanna': 1863,
#  'huh': 853,
#  'also': 150,
#  'many': 1065,
#  'quote': 1395,
#  'without': 1938,
#  'self': 1508,
#  'mean': 1081,
#  'married': 1070,
#  'cause': 343,
#  'hurt': 856,
#  'wit': 1936,
#  'dis': 513,
#  'save': 1480,
#  'relation': 1427,
#  'leaf': 961,
#  'project': 1379,
#  'meeting': 1088,
#  'ok lor': 1244,
#  'l8r': 932,
#  'pls pls': 1336,
#  'cheer': 363,
#  'wk': 1940,
#  'getting': 708,
#  'yijue': 1989,
#  'second': 1495,
#  'haha': 781,
#  'person': 1301,
#  'did': 498,
#  'where': 1918,
#  'see you': 1502,
#  'working': 1955,
#  'except': 605,
#  'saturday': 1478,
#  'sunday': 1646,
#  'cant': 326,
#  'thk': 1717,
#  'oredi': 1269,
#  'page': 1281,
#  'have': 796,
#  'kind': 925,
#  'start': 1613,
#  'link': 991,
#  'open': 1260,
#  'freephone': 669,
#  'use': 1821,
#  'plane': 1324,
#  'month': 1135,
#  'end': 571,
#  'god': 727,
#  'google': 744,
#  'lot': 1030,
#  'especially': 586,
#  'since': 1549,
#  'pie': 1316,
#  'minute': 1108,
#  '2nd': 65,
#  '900': 108,
#  'yesterday': 1987,
#  'collection': 392,
#  '2nd attempt': 66,
#  '900 prize': 109,
#  'claim call': 374,
#  'glad': 717,
#  'following': 649,
#  'dreams': 540,
#  'want come': 1865,
#  'boy': 265,
#  'gal': 687,
#  'mind': 1105,
#  'frnds': 677,
#  'hit': 820,
#  'girl': 713,
#  'ran': 1399,
#  'hell': 806,
#  'her': 810,
#  'asked': 186,
#  'hw': 859,
#  'run': 1469,
#  'fast': 621,
#  'replied': 1432,
#  'boost': 254,
#  'our': 1276,
#  'moral': 1138,
#  'story': 1629,
#  'hv': 858,
#  'msgs': 1156,
#  'chennai': 364,
#  'went': 1911,
#  'bed': 230,
#  'every': 595,
#  'hour': 844,
#  'wanted': 1870,
#  'worry': 1958,
#  'cold': 390,
#  'wont': 1950,
#  'same': 1476,
#  'ex': 601,
#  'awake': 200,
#  'noon': 1211,
#  'nobody': 1203,
#  'eat': 558,
#  'dad': 462,
#  'havent': 797,
#  'whether': 1919,
#  'discount': 514,
#  'ha': 778,
#  'walk': 1857,
#  'hotel': 843,
#  'leaving': 966,
#  'thanx': 1696,
#  'spent': 1608,
#  'baby': 208,
#  'wow': 1962,
#  'dog': 521,
#  'check': 360,
#  'ago': 136,
#  'pa': 1280,
#  'doc': 519,
#  'pain': 1282,
#  'med': 1085,
#  'mom': 1130,
#  'kick': 923,
#  'usual': 1826,
#  'sch': 1486,
#  'come back': 399,
#  'slowly': 1562,
#  'finally': 634,
#  'within': 1937,
#  'grins': 759,
#  'head': 800,
#  'forget': 653,
#  'smile': 1565,
#  'winner': 1932,
#  'specially': 1605,
#  '1000': 21,
#  '2000': 50,
#  'live': 995,
#  '7pm': 90,
#  'cost': 431,
#  '10p': 24,
#  'specially selected': 1606,
#  'receive 1000': 1417,
#  '1000 cash': 22,
#  'cash 2000': 337,
#  'speak live': 1601,
#  'live operator': 997,
#  'operator claim': 1262,
#  '7pm cost': 91,
#  'cost 10p': 432,
#  'do': 518,
#  'street': 1631,
#  'inside': 884,
#  'mayb': 1077,
#  'remove': 1430,
#  've got': 1834,
#  'aft': 130,
#  'everything': 599,
#  'studying': 1634,
#  'surfing': 1656,
#  'lazy': 958,
#  'logo': 1016,
#  'lover': 1040,
#  'name': 1172,
#  'joined': 908,
#  'eve': 591,
#  'ad': 122,
#  'awesome': 205,
#  'bit': 242,
#  'll see': 1003,
#  'school': 1488,
#  'pay': 1291,
#  'like that': 986,
#  'center': 348,
#  'future': 686,
#  'hows': 848,
#  'library': 978,
#  'trouble': 1763,
#  'again': 133,
#  'small': 1564,
#  'happens': 789,
#  'medical': 1086,
#  'insurance': 885,
#  'able': 112,
#  'deliver': 490,
#  'basic': 218,
#  'care': 332,
#  'currently': 454,
#  'shopping': 1534,
#  'til': 1723,
#  'friday': 671,
#  'guide': 775,
#  'right now': 1450,
#  'escape': 585,
#  'theatre': 1701,
#  'now going': 1222,
#  'bus': 279,
#  'soon': 1588,
#  'otherwise': 1275,
#  'omg': 1249,
#  '10': 17,
#  'sure': 1654,
#  'dat': 468,
#  'make sure': 1061,
#  'tel': 1674,
#  'shall': 1529,
#  'put': 1386,
#  'why': 1923,
#  'anyway': 171,
#  'seriously': 1520,
#  'light': 981,
#  'shit': 1532,
#  'and': 157,
#  'point': 1345,
#  'date': 469,
#  'welcome': 1906,
#  'using': 1825,
#  'valentine': 1828,
#  'fb': 624,
#  'ugh': 1788,
#  'show': 1536,
#  'meh': 1089,
#  'weight': 1904,
#  'gee': 696,
#  'lei': 969,
#  'haf': 780,
#  'dunno lei': 551,
#  'dun haf': 548,
#  'alone': 146,
#  'break': 268,
#  'don': 526,
#  'crazy': 442,
#  'lady': 935,
#  'draw': 537,
#  'think so': 1712,
#  'registered': 1426,
#  '21': 57,
#  'inviting': 889,
#  'ac': 115,
#  'frnd': 676,
#  '62468': 87,
#  'inviting friend': 890,
#  'reply yes': 1436,
#  'sms ac': 1569,
#  'stop send': 1626,
#  'send stop': 1514,
#  'oops': 1259,
#  'trip': 1762,
#  'planning': 1326,
#  'together': 1736,
#  'coming home': 405,
#  'hr': 850,
#  'pete': 1304,
#  'ring': 1451,
#  'credit': 443,
#  'hungry': 854,
#  'sucks': 1640,
#  'mark': 1068,
#  'worried': 1957,
#  'sick': 1542,
#  'pizza': 1321,
#  'started': 1614,
#  'before': 232,
#  'fun': 684,
#  'last week': 948,
#  'tv': 1774,
#  'flower': 648,
#  'win 100': 1930,
#  'alex': 142,
#  'woke': 1944,
#  'fall': 613,
#  'asleep': 189,
#  'weather': 1891,
#  'already': 147,
#  'eating': 560,
#  'wat now': 1875,
#  'year old': 1980,
#  'return': 1443,
#  'ticket': 1722,
#  'kerala': 922,
#  'go back': 720,
#  'nxt': 1231,
#  'whats': 1915,
#  'happy birthday': 792,
#  'umma': 1791,
#  'loan': 1008,
#  'will': 1928,
#  'can get': 322,
#  'text back': 1685,
#  'back help': 210,
#  'pilate': 1318,
#  'only': 1256,
#  'hmmm': 823,
#  'kb': 919,
#  'power': 1360,
#  'yoga': 1991,
#  'forgot': 654,
#  'take care': 1663,
#  'write': 1963,
#  'hand': 786,
#  'nice': 1191,
#  'opinion': 1263,
#  'used': 1822,
#  'busy': 280,
#  'goodnight': 743,
#  'alrite': 149,
#  'wrong': 1964,
#  'sweet': 1658,
#  'lar': 943,
#  'wif': 1925,
#  'merry': 1095,
#  'christmas': 370,
#  'guaranteed': 766,
#  'gift': 711,
#  'guaranteed 1000': 767,
#  'someone': 1579,
#  'drug': 545,
#  'of': 1234,
#  'wil': 1927,
#  'read': 1409,
#  'town': 1756,
#  'adult': 128,
#  'now 150p': 1221,
#  'moment': 1131,
#  'file': 629,
#  'remember': 1429,
#  'download': 536,
#  'excuse': 606,
#  'reference': 1424,
#  'rock': 1458,
#  'cant pick': 328,
#  'pick phone': 1310,
#  'phone right': 1306,
#  'now pls': 1223,
#  ...}

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB()
nb.fit(X_train,Y_train)
# Out:
# MultinomialNB()

# %%
Y_pred = nb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

accuracy_score(Y_test, Y_pred)
# Out:
# 0.9808612440191388

# %%
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1440
#            1       1.00      0.87      0.93       232
#
#     accuracy                           0.98      1672
#    macro avg       0.99      0.93      0.96      1672
# weighted avg       0.98      0.98      0.98      1672
